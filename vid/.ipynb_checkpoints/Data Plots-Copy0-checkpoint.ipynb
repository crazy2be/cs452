# %%
# %pylab inline
file = open('4/data.txt')
dataX = []
dataY = []
prevPos = (0, 0)

for (i, l) in enumerate(file):
    l = l[len('Center: for 579:   '):]
    pos = tuple([float(n) for n in l[1:-2].split(',')][:-1])
    d = sqrt((pos[0]-prevPos[0])**2 + (pos[1]-prevPos[1])**2)
    prevPos = pos
    if d > 50: continue # Ignore the really fucked points
    dataX.append(i/float(30)) # Assume 30fps
    dataY.append(d)
   
dataX = np.asarray(dataX)
dataY = np.asarray(dataY)
dataYS = np.convolve(dataY, np.ones(20)/20)
dataYSi = [i for (i, d) in enumerate(dataY) if abs(d - dataYS[i]) < 5]
dataYSS = dataY[dataYSi]
dataXSS = dataX[dataYSi]
dataXSSS = dataXSS
dataYSSS = np.convolve(dataYSS, np.ones(20)/20)[10:-9]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
figure(figsize=(20,10))
plt.scatter(dataXSSS[:], dataYSSS[:])

# %%
figure(figsize=(20,10))
plt.scatter(dataXSSS[2770:3010], dataYSSS[2770:3010])

# %%
figure(figsize=(20,10))
#plt.scatter(dataX[2100:2350], dataY[2100:2350])
#plt.scatter(dataX[:], dataY[:])
def r(start, style=''):
    return [dataXSS[:175], dataYSS[start:start+175], style]

def f1(start, style=''):
    xx, yy = dataXSS[:175], dataYSS[start:start+175]
    p = polyfit(xx, yy, 4)
    ff = np.poly1d(p)
    return [xx, ff(xx), style]

pltargs = reduce(lambda a, b: a + b, [r(150, 'ro'), r(510), r(925), r(1240), f1(150, 'y-')], [])
#plt.plot(*pltargs)
print dataXSSS.shape, dataYSSS.shape
xxx = dataXSSS[120:255]
yyy = dataYSSS[120:255]
xx = dataXSSS[100:275]
yy = dataYSSS[100:275]
p = polyfit(xxx, yyy, 5)
ff = np.poly1d(p)
print p
plt.plot(*([xx, yy, xxx, ff(xxx)]))
 
   #return lambda t: a * np.power(t, 3) + b * np.power(t, 2) + d

#plt.scatter(dataX[2100:2350], dataY[2100:2350])
#plt.plot(dataX[lo:hi], dataY[lo:hi], 'bo', dataX[lo:hi], f0(dataX[lo:hi] - lo), 'k')
# Out:
# (5257,) (5257,)
# [ -4.08987481e-02   1.45680707e+00  -2.03571686e+01   1.39971596e+02
#   -4.73551060e+02   6.30633384e+02]
# [<matplotlib.lines.Line2D at 0x7f4eba054b90>,
#  <matplotlib.lines.Line2D at 0x7f4eba054e10>]

# %%
figure(figsize=(20,10))
#plt.scatter(dataX[2100:2350], dataY[2100:2350])
#plt.scatter(dataX[:], dataY[:])
xx, yy = dataXSSS[325:430], dataYSSS[325:430]
xxx, yyy = dataXSSS[335:430], dataYSSS[335:430]
p = polyfit(xxx, yyy, 5)
ff = np.poly1d(p)
print ff
print xxx
print ff(xxx)
plt.plot(xx, yy, xxx, ff(xxx))
# Out:
#         5        4         3        2
# 0.3019 x - 21.5 x + 611.5 x - 8683 x + 6.152e+04 x - 1.74e+05
# [ 12.46666667  12.5         12.53333333  12.56666667  12.6         12.63333333
#   12.66666667  12.7         12.73333333  12.76666667  12.8         12.83333333
#   12.86666667  12.9         12.93333333  12.96666667  13.          13.03333333
#   13.06666667  13.1         13.13333333  13.16666667  13.2         13.23333333
#   13.26666667  13.3         13.33333333  13.36666667  13.4         13.43333333
#   13.46666667  13.5         13.53333333  13.56666667  13.6         13.63333333
#   13.66666667  13.7         13.73333333  13.76666667  13.8         13.83333333
#   13.86666667  13.9         13.93333333  13.96666667  14.          14.03333333
#   14.06666667  14.1         14.13333333  14.16666667  14.2         14.23333333
#   14.26666667  14.3         14.33333333  14.36666667  14.4         14.43333333
#   14.46666667  14.5         14.53333333  14.56666667  14.6         14.63333333
#   14.66666667  14.7         14.73333333  14.76666667  14.8         14.83333333
#   14.86666667  14.9         14.93333333  14.96666667  15.          15.03333333
#   15.06666667  15.1         15.13333333  15.16666667  15.2         15.23333333
#   15.26666667  15.3         15.33333333  15.36666667  15.4         15.43333333
#   15.46666667  15.5         15.53333333  15.56666667  15.6       ]
# [ 13.80472324  13.73563394  13.64480702  13.53404086  13.40505736
#   13.25950348  13.09895268  12.92490645  12.73879577  12.5419826
#   12.3357614   12.12136062  11.89994414  11.67261283  11.44040598
#   11.20430283  10.96522406  10.72403325  10.48153841  10.23849344
#    9.99559963   9.75350717   9.5128166    9.27408035   9.03780419
#    8.80444875   8.57443098   8.34812567   8.12586694   7.9079497
#    7.69463117   7.48613238   7.28263961   7.08430594   6.89125271
#    6.70357101   6.52132317   6.34454428   6.17324364   6.00740627
#    5.84699442   5.69194902   5.5421912    5.39762377   5.25813271
#    5.12358869   4.99384851   4.86875661   4.7481466    4.63184269
#    4.51966122   4.41141214   4.30690049   4.20592792   4.10829416
#    4.01379851   3.92224131   3.8334255    3.74715804   3.66325143
#    3.5815252    3.50180739   3.42393607   3.3477608    3.27314412
#    3.19996307   3.12811066   3.05749735   2.98805258   2.91972621
#    2.85249006   2.78633936   2.72129426   2.65740134   2.59473505
#    2.53339926   2.4735287    2.41529048   2.35888559   2.30455034
#    2.25255793   2.20321985   2.15688746   2.11395341   2.07485317
#    2.0400665    2.01011898   1.98558343   1.96708147   1.95528499
#    1.95091761   1.95475622   1.96763242   1.99043406   2.02410669]
# [<matplotlib.lines.Line2D at 0x7f4eb9e0fc10>,
#  <matplotlib.lines.Line2D at 0x7f4eb9e0fe90>]

# %%
def myFunc(x):
    return 0.3019*(x**5) - 21.5*(x**4) + 611.5*(x**3) - 8683*(x**2) + 61520*x - 174000
print myFunc(15.5)
plt.plot(xx, myFunc(xx))
# Out:
# -264.384784375

# %%
figure(figsize=(20,10))
xx, yy = dataXSSS[300:430], dataYSSS[300:430]
xxx, yyy = dataXSSS[310:430], dataYSSS[310:430]
p = polyfit(xxx, yyy, 5)
ff = np.poly1d(p)

xx2, yy2 = dataXSSS[675:800], dataYSSS[675:800]
xxx2, yyy2 = dataXSSS[685:800], dataYSSS[685:800]
p2 = polyfit(xxx2, yyy2, 5)
ff2 = np.poly1d(p2)
print p
print p2
plt.plot(xx, yy, xxx, ff(xxx), xx2-435, yy2, xxx2-435, ff2(xxx2))
# Out:
# [  2.75499174e-09  -6.20757140e-06   5.57325743e-03  -2.49114639e+00
#    5.54033977e+02  -4.90068920e+04]
# [  3.65822489e-09  -1.62291432e-05   2.87746550e-02  -2.54863752e+01
#    1.12764046e+04  -1.99372605e+06]
# [<matplotlib.lines.Line2D at 0x7f4ebbe1d4d0>,
#  <matplotlib.lines.Line2D at 0x7f4ebbe1d750>,
#  <matplotlib.lines.Line2D at 0x7f4ebbe1de10>,
#  <matplotlib.lines.Line2D at 0x7f4ebbe27490>]
