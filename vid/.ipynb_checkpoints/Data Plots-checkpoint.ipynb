# %%
# %pylab inline
import csv
file = open('4/data.txt')
dataX = []
dataY = []
prevPos = (0, 0)
import math
#for (i, l) in enumerate(file):
#    l = l[len('Center: for 579:   '):]
#    pos = tuple([float(n) for n in l[1:-2].split(',')][:-1])
f = open('points.csv')
csvreader = csv.reader(f)
for fields in csvreader:
    pos = (float(fields[1]), float(fields[2]))
    if math.isnan(pos[0]) or math.isnan(pos[1]):
        continue
    d = sqrt((pos[0]-prevPos[0])**2 + (pos[1]-prevPos[1])**2)
    prevPos = pos
    if d > 50: continue # Ignore the really fucked points
    dataX.append(float(fields[0])/float(30)) # Assume 30fps
    dataY.append(d)
   
dataX = np.asarray(dataX)
dataY = np.asarray(dataY)
dataYS = np.convolve(dataY, np.ones(20)/20)
dataYSi = [i for (i, d) in enumerate(dataY) if abs(d - dataYS[i]) < 5]
dataYSS = dataY[dataYSi]
dataXSS = dataX[dataYSi]
dataXSSS = dataXSS
dataYSSS = np.convolve(dataYSS, np.ones(20)/20)[10:-9]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
figure(figsize=(20,10))
plt.scatter(dataXSSS[:], dataYSSS[:])

# %%
#figure(figsize=(20,10))
lo1, hi1 = 2280, 2550
x1 = dataX[lo1:hi1]
y1 = dataY[lo1:hi1]
lo2, hi2 = 8770, 9040
x2 = dataX[lo2:hi2]
y2 = dataY[lo2:hi2]
plt.scatter(x1, y1)
plt.show()
plt.scatter(x2, y2)

# %%
import scipy.optimize
import scipy.integrate
get_mean = lambda lst: sum(lst) / len(lst)

# fit a curve using non-linear optimization, with constraints

def fit_nlp(xs, ys):
    v0 = numpy.mean(ys[0:10])
    v1 = numpy.mean(ys[-10:])
    
    offset = xs.min()
    t1 = xs.max() - offset

    def sqerr(coefs):
        return sum([(y - np.poly1d(coefs)(x - offset))**2 for x, y in zip(xs, ys)])

    def slope(coefs, x):
        n = coefs.shape[0]
        xs = np.power(np.full(n - 1, x), np.arange(n - 2, -1, -1)) * np.arange(n - 1, 0, -1)
        return np.dot(xs, coefs[:-1])

    constraints = ( # all constraints should equal 0
        lambda coefs: np.poly1d(coefs)(0) - v0,
        lambda coefs: np.poly1d(coefs)(t1) - v1,
        lambda coefs: slope(coefs, 0),
        lambda coefs: slope(coefs, t1),
    )

    guess = np.full(6, 0)

    solution = scipy.optimize.fmin_slsqp(sqerr, guess, constraints)

    return (solution, offset)

solution, offset = fit_nlp(x1, y1)
model = np.poly1d(solution)

print(solution)
#print(list(map(lambda f: f(solution), constraints)))
#print(model(0))
#print(model(hi-lo))
#print(slope(solution, 0))
#print(slope(solution, hi - lo))

#print(guess)
#print(list(map(lambda f: f(guess), constraints)))

figure(figsize=(20,6))
plt.plot(x1 - offset, y1, 'bo', x1 - offset, model(x1 - offset), 'k')
plt.show()
print(scipy.integrate.quad(model, 0, t1))

def distance(xs, ys):
    return numpy.sum(ys[:-1] * (xs[1:] - xs[:-1]))

print(distance(x1, y1))

offset2 = x2.min()
t2 = x2.max() - offset2
figure(figsize=(20,6))

solution2, offset2 = fit_nlp(x2, y2)
model2 = np.poly1d(solution2)
print(numpy.mean(y2[0:10]) / numpy.mean(y1[0:10]))
plt.plot(x2 - offset2, y2, 'bo', x2 - offset2, model2(x2 - offset2), 'k',  x2 - offset2, model((x2 - offset2) * 0.9) * 0.63, 'r')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 57.8406468142
#             Iterations: 7
#             Function evaluations: 65
#             Gradient evaluations: 7
# [  1.77257485e-03  -4.80108734e-02   4.58509221e-01  -1.64144969e+00
#   -8.03997579e-21   9.50222278e+00]
# (28.706251367607038, 3.187034121899472e-13)
# 28.8778404303
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 59.7375629861
#             Iterations: 6
#             Function evaluations: 72
#             Gradient evaluations: 6
# 0.633299059145
# [<matplotlib.lines.Line2D at 0x7fd45cce0bd0>,
#  <matplotlib.lines.Line2D at 0x7fd45cce0e10>,
#  <matplotlib.lines.Line2D at 0x7fd45ccec510>]

# %%
lo3, hi3 = 2600, 2900
x3 = dataX[lo3:hi3]
y3 = dataY[lo3:hi3]
figure(figsize=(20,6))
plt.scatter(x3, y3)
