# %%
# %pylab inline
from PIL import Image
import skimage

first = Image.open('vid/bmp/0469.bmp')
img = Image.open('vid/bmp/0477.bmp')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dfirst = first.getdata()
d = img.getdata()
img2 = skimage.img_as_float('vid/bmp/0469.bmp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-7a528dd779e5> in <module>()
#       1 dfirst = first.getdata()
#       2 d = img.getdata()
# ----> 3 img2 = skimage.img_as_float('vid/bmp/0469.bmp')
#
# NameError: name 'skimage' is not defined

# %%
print d.getpixel((1, 1))
print d.chop_difference(dfirst)
d
plt.imshow(first)
#plt.imshow(img)
# Out:
# (146, 148, 95)
# ...

# %%
import skimage
import skimage.filters

img3 = skimage.img_as_float(Image.open('vid/bmp/0469.bmp'))
img4 = skimage.img_as_float(Image.open('vid/bmp/0581.bmp'))
    
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20, 12))
filtered = numpy.absolute(img4 - img3)
ax[0, 0].imshow(img3)
ax[0, 1].imshow(img4)
ax[1, 0].imshow(img4 - img3)
ax[1, 1].imshow(filtered)

# %%
nosmall = filtered.copy()
nosmall[nosmall < 0.5] = 0
plt.imshow(nosmall)

# %%
import scipy
scipy.ndimage.measurements.center_of_mass(nosmall)
# Out:
# (476.09847044566527, 1681.0415419160113, 1.0542215878819796)
